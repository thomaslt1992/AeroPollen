# %%
import pandas as pd
import numpy as np
from aeropollen.methods import calculate_ps

df = pd.DataFrame({
    "Date": pd.date_range("2023-03-01", "2023-06-30"),
    "Poaceae": np.random.randint(0, 100, 122),
    "Betula": np.random.randint(0, 80, 122)
})

res = calculate_ps(df, method="percentage")
print(res)
# Out:
#   pollen_type  season season_start season_end  peak_date  season_start_doy  \
# 0     Poaceae    2023   2023-03-05 2023-06-21 2023-03-14                64
# 1      Betula    2023   2023-03-05 2023-06-25 2023-03-14                64
#
#    season_end_doy  peak_doy  ps_length  pollen_integral status
# 0             172        73        109           5831.0     ok
# 1             176        73        113           5093.0     ok
